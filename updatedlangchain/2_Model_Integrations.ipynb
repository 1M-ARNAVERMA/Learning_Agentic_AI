# %% [markdown]
# ## Model Integration with OpenAI, Grok and Gemini

# %%
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model(
    model_name="gpt-4o"
    )
model

# %%
## Invoke the model
response = model.invoke("Hello, how are you?")
response
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 ## Invoke the model
# ----> 2 response = model.invoke("Hello, how are you?")
#       3 response
#
# File d:\Codings\Langchain_Learning\.venv\lib\site-packages\langchain\chat_models\base.py:758, in _ConfigurableModel.invoke(self, input, config, **kwargs)
#     751 @override
#     752 def invoke(
#     753     self,
#    (...)
#     756     **kwargs: Any,
#     757 ) -> Any:
# --> 758     return self._model(config).invoke(input, config=config, **kwargs)
#
# File d:\Codings\Langchain_Learning\.venv\lib\site-packages\langchain\chat_models\base.py:693, in _ConfigurableModel._model(self, config)
#     691 def _model(self, config: RunnableConfig | None = None) -> Runnable[Any, Any]:
#     692     params = {**self._default_config, **self._model_params(config)}
# --> 693     model = _init_chat_model_helper(**params)
#     694     for name, args, kwargs in self._queued_declarative_operations:
#     695         model = getattr(model, name)(*args, **kwargs)
#
# TypeError: _init_chat_model_helper() missing 1 required positional argument: 'model'
