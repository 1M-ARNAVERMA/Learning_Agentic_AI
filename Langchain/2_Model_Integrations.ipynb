# %% [markdown]
# ## Model Integration with OpenAI, Grok and Gemini

# %%
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash"
    #google_api_key=os.getenv("GEMINI_API_KEY")
)
model
# Out:
# ChatGoogleGenerativeAI(metadata={'lc_versions': {'langchain-core': '1.5.3', 'langchain': '1.3.14', 'langchain-google-genai': '4.3.3'}}, output_version=None, profile={'name': 'Gemini 2.5 Flash', 'release_date': '2025-06-17', 'last_updated': '2025-06-17', 'open_weights': False, 'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), location=None, model='gemini-2.5-flash', client=<google.genai.client.Client object at 0x000001FE7F183640>, default_metadata=(), model_kwargs={})

# %%
## Invoke the model
response = model.invoke("Hello, how are you?")
response
# Out:
# AIMessage(content="Hello! I'm doing well, thank you for asking.\n\nHow about you?", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a00412-05c8-7513-ba48-f4186b017c63-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7, 'output_tokens': 127, 'total_tokens': 134, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 109}})

# %%
response.content
# Out:
# "Hello! I'm doing well, thank you for asking.\n\nHow about you?"

# %% [markdown]
# ### Streaming

# %%
for chunk in model.stream("Why do parrots have colorful feathers?"):
    print(chunk.text, end="|", flush=True)
# Out:
# Parrots are renowned for their stunning, vibrant plumage, and| there isn't one single reason for this, but rather a combination of evolutionary pressures and biological mechanisms.
#
# Here are the main reasons why parrots have such colorful feathers:
#
# 1.  **Sexual Selection and Mate Attraction:**
#     *   This is| perhaps the most significant factor. Bright, healthy, and intricate feather patterns often signal to potential mates that an individual is robust, has good genes, is free from parasites, and is capable of finding sufficient food (which is often necessary to produce certain| pigments).
#     *   In many species, the healthier and more vibrant a bird's colors, the more attractive it is to potential partners.
#
# 2.  **Species Recognition:**
#     *   In diverse environments with many different| bird species, distinct color patterns help parrots recognize members of their own species. This prevents hybridization and ensures they mate with the correct species, which is crucial for passing on genes successfully.
#     *   Specific patches of color on the head, wings,| or tail can act like "ID badges."
#
# 3.  **Camouflage (Counter-intuitive but true in context):**
#     *   While we might think of bright colors as making an animal stand out, in their natural habitats| (dense, tropical rainforests with dappled sunlight, colorful flowers, and fruits), these colors can actually provide excellent camouflage.
#     *   Green feathers blend perfectly with the canopy leaves. Patches of red, blue, or yellow can mimic fruits|, flowers, or even the shifting patterns of sunlight filtering through the foliage, breaking up the bird's outline.
#     *   Predators often see the world differently than humans, and from a distance or at certain angles, a seemingly| bright parrot can disappear into the visual "noise" of the rainforest.
#
# 4.  **Signaling Health and Fitness:**
#     *   Producing and maintaining vibrant, healthy feathers is an energy-intensive process. Dull or faded feathers can indicate illness|, poor nutrition, or stress.
#     *   Therefore, a parrot displaying brilliant plumage is essentially advertising its good health and strong physical condition to both potential mates and rivals.
#
# 5.  **Protection:**
#     *   Some pigments, like melan|ins, not only provide color (blacks, browns, grays) but also add structural integrity to feathers, making them more resistant to wear and tear.
#     *   Other pigments might offer some protection against UV radiation.
#
# **How Par|rots Get Their Colors (The Biology):**
#
# Parrot colors come from two main sources:
#
# *   **Pigments:**
#     *   **Melanin:** Produces black, brown, gray, and some yellow colors.
#     *|   **Carotenoids:** These produce reds, oranges, and yellows. Parrots, like many other birds, obtain carotenoids from their diet (fruits, seeds, nectar).
#     *   **Psittacofulvins:** This| is unique to parrots! Unlike carotenoids, psittacofulvins are pigments that parrots *synthesize themselves* within their bodies. These pigments are responsible for many of the brilliant reds, oranges, and yellows that are characteristic of parrots.
# |*   **Structural Coloration:**
#     *   Blues, greens, and iridescent (shimmering) colors are often not due to a blue or green pigment. Instead, they are created by the microscopic structure of the feather barbs|. These structures scatter light in such a way that only certain wavelengths (like blue) are reflected, while others are absorbed. When structural blue is combined with a yellow pigment (like psittacofulvin), it produces green.
#
# In| essence, a parrot's colorful plumage is a magnificent evolutionary adaptation that helps them thrive in their complex and visually rich environments.||

# %% [markdown]
# ### Batch

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "What is the capital of France?",
    "what is the capital of Germany?"
])
for response in responses:
    print(response.content)
# Out:
# Parrots have colorful feathers due to a fascinating combination of **evolutionary advantages** and **unique biological mechanisms**. It's not just for beauty; their vibrant plumage serves several crucial purposes in their natural habitats.
#
# Here's a breakdown:
#
# ### Evolutionary Advantages (Why it's beneficial):
#
# 1.  **Mating and Sexual Selection:** This is a primary driver.
#     *   **Display of Fitness:** Bright, well-maintained feathers signal to potential mates that a parrot is healthy, well-fed, and has good genes. Producing and maintaining such vibrant colors requires energy and resources, so a dull-feathered bird might indicate illness or poor foraging ability.
#     *   **Attracting Mates:** In many parrot species, the brighter or more complex the coloration, the more attractive an individual is to a potential partner.
#
# 2.  **Camouflage (Counter-intuitive but true!):**
#     *   While a bright red or blue parrot might seem to stick out, consider their natural environment: dense tropical forests. These habitats are full of vibrant flowers, fruits, and dappled sunlight. A bright green parrot can disappear perfectly among the leaves, and even a red or blue one can blend in with colorful blossoms, fruits, or the varying light and shadow of the canopy.
#     *   **Disruptive Coloration:** Patches of bright colors can break up a bird's outline, making it harder for predators to distinguish its shape against the complex background of the forest.
#
# 3.  **Communication and Social Signaling:**
#     *   **Species Recognition:** Different parrot species often have distinct color patterns, helping them identify and interact with their own kind within diverse flocks.
#     *   **Flock Cohesion:** In large, noisy flocks, visual signals like bright colors can help individuals stay together and communicate over distances or amidst dense foliage.
#     *   **Status Signaling:** In some species, color intensity or specific patterns might indicate dominance or social status within the flock.
#
# 4.  **Indicator of Health and Diet:**
#     *   The vibrancy of certain colors (especially yellows and reds) can be influenced by the parrot's diet. A parrot that can forage for the right nutrients to produce rich colors is likely a healthy one.
#
# ### Biological Mechanisms (How they get their colors):
#
# Parrots achieve their stunning colors through two main methods:
#
# 1.  **Pigments:** These are chemical compounds in the feathers that absorb certain wavelengths of light and reflect others.
#     *   **Psittacofulvins:** These are unique pigments found *only* in parrots, responsible for their brilliant reds, oranges, and yellows. Unlike carotenoids (which many other birds get from their diet), psittacofulvins are synthesized by the parrots themselves.
#     *   **Melanin:** This pigment produces blacks, browns, and grays. It can also contribute to duller yellows and reds when combined with other pigments.
#
# 2.  **Structural Colors:** These colors are not due to pigments but to the microscopic structure of the feathers.
#     *   **Light Scattering:** The arrangement of tiny air pockets, keratin layers, and other microstructures within the feather barbs scatters specific wavelengths of light.
#     *   **Blues and Greens:** This is how parrots produce their vibrant blues and many of their greens (often a combination of structural blue overlaid with yellow psittacofulvin pigment). The light is scattered in such a way that only blue light is reflected back to our eyes.
#
# In summary, the colorful feathers of parrots are a beautiful testament to evolution, allowing them to thrive in their complex environments by attracting mates, camouflaging, communicating, and signaling their health, all thanks to specialized pigments and feather structures.
# The capital of France is **Paris**.
# The capital of Germany is **Berlin**.
