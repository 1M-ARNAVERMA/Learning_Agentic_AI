# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model = 'gemini-2.5-flash'
)
model
# Out:
# ChatGoogleGenerativeAI(metadata={'lc_versions': {'langchain-core': '1.5.3', 'langchain': '1.3.14', 'langchain-google-genai': '4.3.3'}}, output_version=None, profile={'name': 'Gemini 2.5 Flash', 'release_date': '2025-06-17', 'last_updated': '2025-06-17', 'open_weights': False, 'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), location=None, model='gemini-2.5-flash', client=<google.genai.client.Client object at 0x0000021597F449D0>, default_metadata=(), model_kwargs={})

# %%
model.invoke("what is AI ?")
# Out:
# AIMessage(content='AI stands for **Artificial Intelligence**.\n\nAt its core, AI refers to the simulation of human intelligence in machines that are programmed to think and learn like humans. It\'s about creating systems that can perform tasks that typically require human cognition.\n\nHere\'s a breakdown of what that means:\n\n1.  **Mimicking Human Cognition:** AI aims to replicate abilities like:\n    *   **Learning:** Acquiring information and rules for using the information.\n    *   **Reasoning:** Using rules to reach approximate or definite conclusions.\n    *   **Problem-solving:** Finding solutions to complex challenges.\n    *   **Perception:** Understanding and interpreting the world through senses (like computer vision for "seeing" or natural language processing for "hearing" and "understanding" language).\n    *   **Language Understanding:** Processing and generating human language.\n    *   **Decision-making:** Choosing the best course of action.\n\n2.  **How it Works (S
# ...

# %% [markdown]
# ## Message Prompts

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

messages = [
    SystemMessage(content="You are a Poetry Expert."),
    HumanMessage(content="Write a poem about the sea."),
]

response = model.invoke(messages)
response.content
# Out:
# "A boundless blue, a shifting, silver gleam,\nThe sea unfurls, a waking, ancient dream.\nHorizon's edge where sky and water meet,\nA pulsing heart, both bitter, wild, and sweet.\n\nIt breathes and sighs, a rhythmic, ceaseless sound,\nWhere foam-white fingers trace the sandy ground.\nA whisper soft, then rising to a roar,\nAs mighty breakers crash upon the shore.\n\nWhat secrets sleep within its emerald deep?\nWhere sunbeams fade and silent shadows creep.\nOld coral cities, wrecks of ships gone down,\nA watery realm, a hidden, sunken town.\n\nIt dances bright beneath the summer sun,\nA million diamonds, sparkling, one by one.\nBut turn its mood, and tempest spirits rise,\nWith thunderous waves and dark, tumultuous skies.\nA raging beast, with fury in its spray,\nThat tears at cliffs and sweeps all hope away.\n\nIt watched the first, it will outlast the last,\nA timeless force, from ages flowing past.\nIt calls the soul, a siren's ancient plea,\nTo lose oneself within its majesty.\nFor
# ...

# %%
human_msg = HumanMessage(
    content="Hello",
    name="alice",
    id= "msg_123"
    )

# %%
response= model.invoke([human_msg])
response
# Out:
# AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a00990-71d6-72f0-82c7-2b58ee084860-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2, 'output_tokens': 35, 'total_tokens': 37, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 26}})

# %%
ai_msg = AIMessage('Id be happy to help you with that!', name='assistant', id='msg_456')

messages = [
    SystemMessage("You are a Helpful assistant."),
    HumanMessage("Write a poem about the sea."),
    ai_msg,
    HumanMessage("Great! What is 2+2?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# 2 + 2 = 4

# %%
response.usage_metadata
# Out:
# {'input_tokens': 34,
#  'output_tokens': 23,
#  'total_tokens': 57,
#  'input_token_details': {'cache_read': 0},
#  'output_token_details': {'reasoning': 16}}
